# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
import pathlib
import csv

# %%
songname = r"C:\Users\user\Downloads\gtzan-genre-collection\genres\blues\blues.00000.au"

# %%
cmap = plt.get_cmap('inferno')

# %%
y , sr = librosa.load(songname, mono=True, duration=30)
spectogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, n_fft=2048, hop_length=1024)
spectogram = librosa.power_to_db(spectogram, ref=np.max)
plt.axes().set_aspect('equal')
plt.imshow(spectogram, origin="lower", cmap=cmap);
plt.axis('off');

# %%
plt.figure(figsize=(10,10))
plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');
plt.axis('off');
plt.savefig('demo.png')

# %%
plt.figure(figsize=(10,10))
genres = ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
mypath = r'C:\Users\user\Downloads\gtzan-genre-collection\genresImages'
if not os.path.exists(mypath):
        os.makedirs(mypath)
for g in genres:
    newpath = r'C:\Users\user\Downloads\gtzan-genre-collection\genresImages\{}'.format(g)
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    for filename in os.listdir(r'C:\Users\user\Downloads\gtzan-genre-collection\genres\{}'.format(g)):
        songname = r'C:\Users\user\Downloads\gtzan-genre-collection\genres\{}\{}'.format(g,filename)
        #print(songname)
        y, sr = librosa.load(songname, mono=True, duration=30)
        plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');
        plt.axis('off');
        plt.savefig(r'C:\Users\user\Downloads\gtzan-genre-collection\genresImages\{}\{}.png'.format(g,filename[:-3].replace(".", "")))
        #plt.savefig(r'C:\Users\user\Downloads\gtzan-genre-collection\genresImages\{}\{}.png'.format(g,filename))
        plt.clf()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:7739: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
